# %%
import pandas as pd

df = pd.read_csv("../data/processed/precious_metals_trade_inflation.csv")

# %%
fig = px.bar(
    bar_data,
    x="metal_group",
    y="trade_value_usd",
    title="Total Trade Value by Metal (1988-2016)",
    labels={"metal_group": "Metal", "trade_value_usd": "Total Trade Value (USD)"},
    color="metal_group",
    color_discrete_map={"Gold": "#FFD700", "Silver": "#C0C0C0", "Platinum": "#E5E4E2"}
)
fig.show()

# %% [markdown]
# ## Summary
# - Gold dominates with ~$3.8 trillion total trade value (1988-2016)
# - Silver is second with ~$1.7 trillion — less than half of Gold
# - Platinum is significantly smaller with ~$400 billion
# - This confirms Gold's role as the primary precious metal in global trade
