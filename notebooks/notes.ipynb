# %%
import kagglehub
import shutil
import os

path = kagglehub.dataset_download("odins0n/monthly-gold-prices")

local_path = "../data_acquisition/monthly-gold-prices.csv"
os.makedirs(local_path, exist_ok=True)
shutil.copytree(path, local_path, dirs_exist_ok=True)
# Out:
# '../data_acquisition/monthly-gold-prices.csv'
